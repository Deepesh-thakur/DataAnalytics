# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("NCHS.csv")

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10864  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10865  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10866  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10867  1999  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                    Cause Name          State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries  United States  169936                     49.4
# 1      Unintentional injuries        Alabama    2703                     53.8
# 2      Unintentional injuries         Alaska     436                     63.7
# 3      Unintentional injuries        Arizona    4184                     56.2
# 4      Unintentional injuries       Arkansas    1625                     51.8
# ...                       ...            ...     ...                      ...
# 10863          Kidney disease       Virginia    1035                     16.9
# 10864          Kidney disease     Washington     278                      5.2
# 10865          Kidney disease  West Virginia     345                     16.4
# 10866          Kidney disease      Wisconsin     677                     11.9
# 10867          Kidney disease        Wyoming      30                      6.8
#
# [10868 rows x 6 columns]

# %% [markdown]
# ## This Study nalysis the leading causes of death in the united states of america between 1999 and 2017.

# %% [markdown]
# ## this case study will try to answer the following questions-

# %% [markdown]
# # Q:1

# %%
What is the total no. of recoreds in the dataset ?

# %%
data.shape
# Out:
# (10868, 6)

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169936                     49.4
# 1  Unintentional injuries        Alabama    2703                     53.8
# 2  Unintentional injuries         Alaska     436                     63.7
# 3  Unintentional injuries        Arizona    4184                     56.2
# 4  Unintentional injuries       Arkansas    1625                     51.8

# %%
data.tail()
# Out:
#        Year                                     113 Cause Name  \
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10864  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10865  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10866  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10867  1999  Nephritis, nephrotic syndrome and nephrosis (N...
#
#            Cause Name          State  Deaths  Age-adjusted Death Rate
# 10863  Kidney disease       Virginia    1035                     16.9
# 10864  Kidney disease     Washington     278                      5.2
# 10865  Kidney disease  West Virginia     345                     16.4
# 10866  Kidney disease      Wisconsin     677                     11.9
# 10867  Kidney disease        Wyoming      30                      6.8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10868 entries, 0 to 10867
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10868 non-null  int64
#  1   113 Cause Name           10868 non-null  object
#  2   Cause Name               10868 non-null  object
#  3   State                    10868 non-null  object
#  4   Deaths                   10868 non-null  int64
#  5   Age-adjusted Death Rate  10868 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 509.6+ KB

# %%
data.isnull()
# Out:
#         Year  113 Cause Name  Cause Name  State  Deaths  \
# 0      False           False       False  False   False
# 1      False           False       False  False   False
# 2      False           False       False  False   False
# 3      False           False       False  False   False
# 4      False           False       False  False   False
# ...      ...             ...         ...    ...     ...
# 10863  False           False       False  False   False
# 10864  False           False       False  False   False
# 10865  False           False       False  False   False
# 10866  False           False       False  False   False
# 10867  False           False       False  False   False
#
#        Age-adjusted Death Rate
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10863                    False
# 10864                    False
# 10865                    False
# 10866                    False
# 10867                    False
#
# [10868 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Year                       0
# 113 Cause Name             0
# Cause Name                 0
# State                      0
# Deaths                     0
# Age-adjusted Death Rate    0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Year                       0
# 113 Cause Name             0
# Cause Name                 0
# State                      0
# Deaths                     0
# Age-adjusted Death Rate    0
# dtype: int64

# %%
data.isna()
# Out:
#         Year  113 Cause Name  Cause Name  State  Deaths  \
# 0      False           False       False  False   False
# 1      False           False       False  False   False
# 2      False           False       False  False   False
# 3      False           False       False  False   False
# 4      False           False       False  False   False
# ...      ...             ...         ...    ...     ...
# 10863  False           False       False  False   False
# 10864  False           False       False  False   False
# 10865  False           False       False  False   False
# 10866  False           False       False  False   False
# 10867  False           False       False  False   False
#
#        Age-adjusted Death Rate
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10863                    False
# 10864                    False
# 10865                    False
# 10866                    False
# 10867                    False
#
# [10868 rows x 6 columns]

# %% [markdown]
# #### There are 10868 death causes were recorded in differeent  U.S states.

# %% [markdown]
# # Q:2

# %%
what were the the causes of death in this dataset ?
# Out:
#   Cell In[15], line 1
#     what were the the causes of death in this dataset ?
#          ^
# SyntaxError: invalid syntax

# %%
data.columns
# Out:
# Index(['Year', '113 Cause Name', 'Cause Name', 'State', 'Deaths',
#        'Age-adjusted Death Rate'],
#       dtype='object')

# %%
data['Cause Name'].unique()
# Out:
# array(['Unintentional injuries', 'All causes', "Alzheimer's disease",
#        'Stroke', 'CLRD', 'Diabetes', 'Heart disease',
#        'Influenza and pneumonia', 'Suicide', 'Cancer', 'Kidney disease'],
#       dtype=object)

# %%
data=data[data['Cause Name']!='All causes']

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10864  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10865  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10866  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10867  1999  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                    Cause Name          State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries  United States  169936                     49.4
# 1      Unintentional injuries        Alabama    2703                     53.8
# 2      Unintentional injuries         Alaska     436                     63.7
# 3      Unintentional injuries        Arizona    4184                     56.2
# 4      Unintentional injuries       Arkansas    1625                     51.8
# ...                       ...            ...     ...                      ...
# 10863          Kidney disease       Virginia    1035                     16.9
# 10864          Kidney disease     Washington     278                      5.2
# 10865          Kidney disease  West Virginia     345                     16.4
# 10866          Kidney disease      Wisconsin     677                     11.9
# 10867          Kidney disease        Wyoming      30                      6.8
#
# [9880 rows x 6 columns]

# %%
data['Cause Name'].unique()
# Out:
# array(['Unintentional injuries', "Alzheimer's disease", 'Stroke', 'CLRD',
#        'Diabetes', 'Heart disease', 'Influenza and pneumonia', 'Suicide',
#        'Cancer', 'Kidney disease'], dtype=object)

# %%
data['Cause Name'].nunique()
# Out:
# 10

# %% [markdown]
# ##### There are 10 death causes

# %% [markdown]
# # Q:3

# %%
How many states in this dataset ?

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169936                     49.4
# 1  Unintentional injuries        Alabama    2703                     53.8
# 2  Unintentional injuries         Alaska     436                     63.7
# 3  Unintentional injuries        Arizona    4184                     56.2
# 4  Unintentional injuries       Arkansas    1625                     51.8

# %%
data.State.unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
data=data[data['State']!='United States']

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 1      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10864  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10865  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10866  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10867  1999  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                    Cause Name          State  Deaths  Age-adjusted Death Rate
# 1      Unintentional injuries        Alabama    2703                     53.8
# 2      Unintentional injuries         Alaska     436                     63.7
# 3      Unintentional injuries        Arizona    4184                     56.2
# 4      Unintentional injuries       Arkansas    1625                     51.8
# 5      Unintentional injuries     California   13840                     33.2
# ...                       ...            ...     ...                      ...
# 10863          Kidney disease       Virginia    1035                     16.9
# 10864          Kidney disease     Washington     278                      5.2
# 10865          Kidney disease  West Virginia     345                     16.4
# 10866          Kidney disease      Wisconsin     677                     11.9
# 10867          Kidney disease        Wyoming      30                      6.8
#
# [9690 rows x 6 columns]

# %%
# Out:
# 36280583

# %% [markdown]
# # Q:4

# %%
what is the number of deaths in the US from 1999 to 2017 ?

# %%
data.Deaths.sum()
# Out:
# 36280583

# %%
The total number of death during period is 36600/....

# %% [markdown]
# # Q:5

# %% [markdown]
# what is the number of deaths per year from 1999 to 2017 ?

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 5  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 1  Unintentional injuries     Alabama    2703                     53.8
# 2  Unintentional injuries      Alaska     436                     63.7
# 3  Unintentional injuries     Arizona    4184                     56.2
# 4  Unintentional injuries    Arkansas    1625                     51.8
# 5  Unintentional injuries  California   13840                     33.2

# %%
data.Deaths.sum()
# Out:
# 36280583

# %%
data1=data.groupby(['Year']).sum()

# %%
data1
# Out:
#        Deaths  Age-adjusted Death Rate
# Year
# 1999  1905826                  35592.3
# 2000  1902194                  35161.3
# 2001  1899358                  34580.3
# 2002  1918873                  34429.2
# 2003  1912115                  33846.1
# 2004  1864133                  32397.1
# 2005  1889981                  32318.8
# 2006  1854676                  31152.8
# 2007  1846301                  30456.4
# 2008  1872981                  30342.3
# 2009  1838501                  29211.4
# 2010  1852349                  29052.7
# 2011  1869321                  28612.3
# 2012  1876588                  28067.9
# 2013  1910311                  27973.4
# 2014  1938408                  27914.7
# 2015  2013017                  28402.1
# 2016  2034119                  28183.5
# 2017  2081531                  28279.9

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.Deaths
# Out:
# Year
# 1999    1905826
# 2000    1902194
# 2001    1899358
# 2002    1918873
# 2003    1912115
# 2004    1864133
# 2005    1889981
# 2006    1854676
# 2007    1846301
# 2008    1872981
# 2009    1838501
# 2010    1852349
# 2011    1869321
# 2012    1876588
# 2013    1910311
# 2014    1938408
# 2015    2013017
# 2016    2034119
# 2017    2081531
# Name: Deaths, dtype: int64

# %%
data1.Deaths.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Q:6

# %%
Which 10 states had the highest no of deaths overall ?

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 5  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 1  Unintentional injuries     Alabama    2703                     53.8
# 2  Unintentional injuries      Alaska     436                     63.7
# 3  Unintentional injuries     Arizona    4184                     56.2
# 4  Unintentional injuries    Arkansas    1625                     51.8
# 5  Unintentional injuries  California   13840                     33.2

# %%
data1=data.groupby('State').sum()

# %%
data1
# Out:
#                         Year   Deaths  Age-adjusted Death Rate
# State
# Alabama               381520   689468                  13754.6
# Alaska                381520    50101                  10959.1
# Arizona               381520   676578                  10531.8
# Arkansas              381520   431902                  13547.0
# California            381520  3594261                  10378.3
# Colorado              381520   440074                  10063.3
# Connecticut           381520   418389                   9865.7
# Delaware              381520   109842                  11482.5
# District of Columbia  381520    69786                  11884.3
# Florida               381520  2533472                  10434.4
# Georgia               381520   984109                  12224.2
# Hawaii                381520   136969                   8870.6
# Idaho                 381520   161414                  10919.9
# Illinois              381520  1508039                  11376.9
# Indiana               381520   837358                  12466.0
# Iowa                  381520   416684                  11008.4
# Kansas                381520   355905                  11335.5
# Kentucky              381520   623018                  13932.8
# Louisiana             381520   607806                  13588.7
# Maine                 381520   186894                  11382.0
# Maryland              381520   619229                  10871.2
# Massachusetts         381520   766310                  10089.9
# Michigan              381520  1313813                  12061.7
# Minnesota             381520   541359                   9528.5
# Mississippi           381520   433661                  14560.7
# Missouri              381520   835348                  12652.3
# Montana               381520   126104                  11179.5
# Nebraska              381520   218158                  10603.1
# Nevada                381520   282665                  12075.2
# New Hampshire         381520   153380                  10795.6
# New Jersey            381520  1030622                  10573.2
# New Mexico            381520   220993                  10914.2
# New York              381520  2264120                  10519.1
# North Carolina        381520  1115953                  11976.7
# North Dakota          381520    88299                  10632.0
# Ohio                  381520  1605250                  12356.6
# Oklahoma              381520   546164                  13926.8
# Oregon                381520   451426                  10698.0
# Pennsylvania          381520  1854953                  11643.4
# Rhode Island          381520   141146                  10769.4
# South Carolina        381520   582793                  12514.1
# South Dakota          381520   107491                  11095.3
# Tennessee             381520   875383                  13505.5
# Texas                 381520  2367695                  11506.8
# Utah                  381520   194022                   9812.5
# Vermont               381520    77898                  10798.4
# Virginia              381520   849570                  11154.9
# Washington            381520   712395                  10771.6
# West Virginia         381520   312416                  13907.2
# Wisconsin             381520   696978                  10917.0
# Wyoming               381520    62920                  11558.1

# %%
data1.reset_index(inplace=True)

# %%
data1.columns
# Out:
# Index(['State', 'Year', 'Deaths', 'Age-adjusted Death Rate'], dtype='object')

# %%
data1=data1.sort_values("Deaths",ascending=False)

# %%
plt.figure(figsize=(15,6))
plt.bar('State','Deaths',data=data1.head(10))
plt.xticks(rotation=45)
plt.title("Top Ten states with highest death number \n 1999-2017")
# Out:
# Text(0.5, 1.0, 'Top Ten statses with highest death number \n 1999-2017')

# %%
plt.figure(figsize=(15,6))
plt.bar('State','Deaths',data=data1.tail(10))
plt.xticks(rotation=45)
plt.title("Bottom Ten states with highest death number \n 1999-2017")
# Out:
# Text(0.5, 1.0, 'Bottom Ten states with highest death number \n 1999-2017')

# %% [markdown]
# # Q:7

# %%
What were the top causes of deaths in the united states during this period ?

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 5  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 1  Unintentional injuries     Alabama    2703                     53.8
# 2  Unintentional injuries      Alaska     436                     63.7
# 3  Unintentional injuries     Arizona    4184                     56.2
# 4  Unintentional injuries    Arkansas    1625                     51.8
# 5  Unintentional injuries  California   13840                     33.2

# %%
data2=data.groupby('Cause Name').sum()

# %%
data2
# Out:
#                             Year    Deaths  Age-adjusted Death Rate
# Cause Name
# Alzheimer's disease      1945752   1494816                  24256.0
# CLRD                     1945752   2594927                  43253.4
# Cancer                   1945752  10843644                 173078.6
# Diabetes                 1945752   1399943                  22677.4
# Heart disease            1945752  12222640                 191798.4
# Influenza and pneumonia  1945752   1094641                  17641.1
# Kidney disease           1945752    858613                  13633.6
# Stroke                   1945752   2726523                  44476.9
# Suicide                  1945752    697016                  13019.9
# Unintentional injuries   1945752   2347820                  42139.2

# %%
data2.sort_values('Deaths',ascending=False,inplace=True)

# %%
data2
# Out:
#                             Year    Deaths  Age-adjusted Death Rate
# Cause Name
# Heart disease            1945752  12222640                 191798.4
# Cancer                   1945752  10843644                 173078.6
# Stroke                   1945752   2726523                  44476.9
# CLRD                     1945752   2594927                  43253.4
# Unintentional injuries   1945752   2347820                  42139.2
# Alzheimer's disease      1945752   1494816                  24256.0
# Diabetes                 1945752   1399943                  22677.4
# Influenza and pneumonia  1945752   1094641                  17641.1
# Kidney disease           1945752    858613                  13633.6
# Suicide                  1945752    697016                  13019.9

# %%
data2.reset_index(inplace=True)

# %%
plt.figure(figsize=(5,6))
plt.bar('Cause Name','Deaths',data=data2.head(3))
plt.xticks(rotation=45)
plt.title("Top 3 causes of Death number \n 1999-2017")
# Out:
# Text(0.5, 1.0, 'Top 3 causes of Death number \n 1999-2017')
